# %%
import pandas as pd
df=pd.read_csv("/amazon - amazon.csv.csv")
df
# Out:
#       product_id                                       product_name  \
# 0     B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...
# 1     B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...
# 2     B0994GP1CX  LS LAPSTER Quality Assured Universal Silicone ...
# 3     B09VT6JKRP  Lapster USB 3.0 A to Micro B SuperSpeed for ha...
# 4     B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# ...          ...                                                ...
# 1460  B07YNTJ8ZM  Zebronics ZEB-COUNTY 3W Wireless Bluetooth Por...
# 1461  B07L3NDN24  ZEBRONICS Zeb-Fame 5watts 2.0 Multi Media Spea...
# 1462  B08CRRQK6Z  Zebronics Zeb-JUKEBAR 3900, 80W Multimedia sou...
# 1463  B07YWS9SP9  Zebronics, ZEB-NC3300 USB Powered Laptop Cooli...
# 1464  B0814ZY6FP  Zebronics ZEB-VITA Wireless Bluetooth 10W Port...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %%
df.head(500)
# Out:
#      product_id                                       product_name  \
# 0    B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...
# 1    B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...
# 2    B0994GP1CX  LS LAPSTER Quality Assured Universal Silicone ...
# 3    B09VT6JKRP  Lapster USB 3.0 A to Micro B SuperSpeed for ha...
# 4    B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# ..          ...                                                ...
# 495  B0BMFD94VD  White Feather Portable Heat Sealer Mini Sealin...
# 496  B01KK0HU3Y  HP Z3700 Wireless Optical Mouse with USB Recei...
# 497  B00ZYLMQH0  Dell KB216 Wired Multimedia USB Keyboard with ...
# 498  B08ZJDWTJ1  Seagate Expansion 1TB External HDD - USB 3.0 f...
# 499  B094QZLJQ6  Seagate One Touch 2TB External HDD with Passwo...
#
#                                               category discounted_price  \
# 0    Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %%
df.tail(500)
# Out:
#       product_id                                       product_name  \
# 965   B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 966   B08CF4SCNP  Quantum QHM-7406 Full-Sized Keyboard with (₹) ...
# 967   B0994GFWBH  Lapster 1.5 mtr USB 2.0 Type A Male to USB A M...
# 968   B0994GFWBH  Lapster 1.5 mtr USB 2.0 Type A Male to USB A M...
# 969   B07W6VWZ8C  Infinity (JBL Fuze Pint, Wireless Ultra Portab...
# ...          ...                                                ...
# 1460  B07YNTJ8ZM  Zebronics ZEB-COUNTY 3W Wireless Bluetooth Por...
# 1461  B07L3NDN24  ZEBRONICS Zeb-Fame 5watts 2.0 Multi Media Spea...
# 1462  B08CRRQK6Z  Zebronics Zeb-JUKEBAR 3900, 80W Multimedia sou...
# 1463  B07YWS9SP9  Zebronics, ZEB-NC3300 USB Powered Laptop Cooli...
# 1464  B0814ZY6FP  Zebronics ZEB-VITA Wireless Bluetooth 10W Port...
#
#                                                category discounted_price  \
# 965   Electronics|HomeTheater,TV&Video|Accessories|C...             ₹309
# ...

# %%
df.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1465 non-null   object
#  1   product_name            1465 non-null   object
#  2   category                1465 non-null   object
#  3   discounted_price        1465 non-null   object
#  4   actual_price            1465 non-null   object
#  5   discount_percentage     1465 non-null   object
#  6   rating                  1465 non-null   object
#  7   cleaning_data_count     1465 non-null   object
#  8   rating_count            1464 non-null   object
#  9   rating_count.1          1465 non-null   object
#  10  user_id                 1465 non-null   object
#  11  clean_user_name         1465 non-null   object
#  12  user_name               1465 non-null   object
#  13  user_name=PROPER(K2)    1465 non-null   object
# ...

# %%
missing_values=df.isnull( ).sum
missing_values
# Out:
# <bound method DataFrame.sum of       product_id  product_name  category  discounted_price  actual_price  \
# 0          False         False     False             False         False
# 1          False         False     False             False         False
# 2          False         False     False             False         False
# 3          False         False     False             False         False
# 4          False         False     False             False         False
# ...          ...           ...       ...               ...           ...
# 1460       False         False     False             False         False
# 1461       False         False     False             False         False
# 1462       False         False     False             False         False
# 1463       False         False     False             False         False
# 1464       False         False     False             False         False
#
# ...

# %%
df.describe( )
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B096MSW6CT  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating cleaning_data_count  \
# count          1465                1465   1465                1465
# unique          449                  92     26                1144
# ...

# %%
df.describe().T
# Out:
#                        count unique  \
# product_id              1465   1351
# product_name            1465   1337
# category                1465    211
# discounted_price        1465    550
# actual_price            1465    449
# discount_percentage     1465     92
# rating                  1465     26
# cleaning_data_count     1465   1144
# rating_count            1464   1143
# rating_count.1          1465   1293
# user_id                 1465   1194
# clean_user_name         1465   1194
# user_name               1465   1194
# user_name=PROPER(K2)    1465   1194
# user_name=PROPER(K2).1  1465   1194
# review_content          1465   1212
# img_link                1465   1412
# product_link            1465   1465
#
#                                                                       top freq
# product_id                                                     B096MSW6CT    3
# product_name            Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...    5
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(columns=['user_name'], axis=1, inplace=True, errors='ignore')

# %%
df.drop(columns=['rating_count'],axis=1, inplace=True, errors="ignore")

# %%
df.drop(columns=['product_link', 'img_link'], axis=1, inplace=True, errors='ignore')

# %% [markdown]
# I've dropped the `product_link` and `img_link` columns as they are often not directly used in Power BI for analysis and can make the dataset larger than necessary. Now, let's check the remaining columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1465 non-null   object
#  1   product_name            1465 non-null   object
#  2   category                1465 non-null   object
#  3   discounted_price        1465 non-null   object
#  4   actual_price            1465 non-null   object
#  5   discount_percentage     1465 non-null   object
#  6   rating                  1465 non-null   object
#  7   cleaning_data_count     1465 non-null   object
#  8   rating_count.1          1465 non-null   object
#  9   user_id                 1465 non-null   object
#  10  clean_user_name         1465 non-null   object
#  11  user_name=PROPER(K2)    1465 non-null   object
#  12  user_name=PROPER(K2).1  1465 non-null   object
#  13  review_content          1465 non-null   object
# dtypes: object(14)
# ...

# %%
df.drop(columns=['user_name=PROPER(K2)', 'user_name=PROPER(K2).1'], axis=1, inplace=True, errors='ignore')

# %% [markdown]
# I've removed the spreadsheet artifact columns. Let's see the updated DataFrame structure.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   cleaning_data_count  1465 non-null   object
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: object(12)
# memory usage: 137.5+ KB

# %% [markdown]
# Now that we have cleaned up the irrelevant columns, let's proceed with converting the data types of the columns that should be numerical. We will start with `discounted_price` and `actual_price` by removing the '₹' symbol and commas, and then converting them to a numeric type (float).

# %%
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   object
#  7   cleaning_data_count  1465 non-null   int64
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 137.5+ KB

# %% [markdown]
# Now that we have cleaned up the irrelevant columns, let's proceed with converting the data types of the columns that should be numerical. We will start with `discounted_price` and `actual_price` by removing the '₹' symbol and commas, and then converting them to a numeric type (float).

# %%
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   object
#  7   cleaning_data_count  1465 non-null   object
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 137.5+ KB

# %% [markdown]
# Next, we will clean the `discount_percentage` column by removing the '%' symbol and converting it to a float. This will enable numerical analysis on the discount values.

# %%
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   object
#  7   cleaning_data_count  1465 non-null   object
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 137.5+ KB

# %% [markdown]
# The `rating` column also needs to be converted to a numerical type for analysis. I will convert 'object' values to `float`.

# %%
df['rating'] = pd.to_numeric(df['rating'].astype(str).str.replace(r'\|', '', regex=True).str.replace(' out of 5 stars', '', regex=False), errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   cleaning_data_count  1465 non-null   int64
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 137.5+ KB

# %%
df['rating'] = pd.to_numeric(df['rating'].astype(str).str.replace(r'\|', '', regex=True).str.replace(' out of 5 stars', '', regex=False), errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   cleaning_data_count  1465 non-null   int64
#  8   user_id              1465 non-null   object
#  9   clean_user_name      1465 non-null   object
#  10  review_content       1465 non-null   object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 126.0+ KB

# %%
df.drop(columns=['rating_count.1'], axis=1, inplace=True, errors='ignore')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   cleaning_data_count  1465 non-null   int64
#  8   user_id              1465 non-null   object
#  9   clean_user_name      1465 non-null   object
#  10  review_content       1465 non-null   object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 126.0+ KB

# %% [markdown]
# Finally, let's clean and convert `cleaning_data_count` and `rating_count.1` to numeric types (integers), as they currently contain commas and are of object type. These columns likely represent counts.

# %%
df.drop(columns=['rating_count.1'], axis=1, inplace=True, errors='ignore')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   cleaning_data_count  1465 non-null   int64
#  8   user_id              1465 non-null   object
#  9   clean_user_name      1465 non-null   object
#  10  review_content       1465 non-null   object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 126.0+ KB

# %% [markdown]
# Now, let's convert the `cleaning_data_count` column to an integer type. This column likely represents counts and needs to be numerical for analysis. We will remove commas before converting.

# %%
df['cleaning_data_count'] = df['cleaning_data_count'].astype(str).str.replace(',', '', regex=False).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   cleaning_data_count  1465 non-null   int64
#  8   user_id              1465 non-null   object
#  9   clean_user_name      1465 non-null   object
#  10  review_content       1465 non-null   object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 126.0+ KB

# %% [markdown]
# Now, let's clean the `discount_percentage` column by removing the '%' symbol and converting it to a float. This will allow for numerical analysis on the discount values.

# %%
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   object
#  7   cleaning_data_count  1465 non-null   object
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 137.5+ KB

# %% [markdown]
# Now that we have cleaned up the irrelevant columns, let's proceed with converting the data types of the columns that should be numerical. We will start with `discounted_price` and `actual_price` by removing the '₹' symbol and commas, and then converting them to a numeric type (float).

# %%
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   cleaning_data_count  1465 non-null   object
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 137.5+ KB

# %%
df.drop(columns=['user_name=PROPER(K2)', 'user_name=PROPER(K2).1'], axis=1, inplace=True, errors='ignore')

# %% [markdown]
# I've removed the spreadsheet artifact columns. Let's see the updated DataFrame structure.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   cleaning_data_count  1465 non-null   object
#  8   rating_count.1       1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  clean_user_name      1465 non-null   object
#  11  review_content       1465 non-null   object
# dtypes: object(12)
# memory usage: 137.5+ KB

# %%
df.to_csv("cleaned_amazon_data.csv", index=False)

# %%
from google.colab import files
files.download("cleaned_amazon_data.csv")
